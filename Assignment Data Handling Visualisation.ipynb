# %%
#importing Libraries

#pandas for converting our csv files into dataframes
import pandas as pd
#numpy for performing mathmetic operations
import numpy as np
#matplot for visualization
import matplotlib.pyplot as plt

# %%
def bar_chart():
 #import Data
 data = pd.read_csv('Desktop/High_score.csv')
 #Sort Data Based on Most Sixes
 highest_batting = data.sort_values(by='6s',ascending=True)
 #Plot The Data
 plt.bar(high_scorer['Player'], high_scorer['6s'])
 #Set X Label as Player Names
 plt.xlabel("Player Name")
 #Set Y label as Most Sixes
 plt.ylabel("Most Sixes")
 #Title of our Chart
 plt.title("Most Sixes in Pakistan Super League")
 #Setting location of Ticks
 plt.xticks(rotation=45)
 #Show Plot
 plt.show()
 # Save as Image
 plt.savefig("bar.png")
 return

# %%
def pie_chart():
 #Import Data Set
 happiness = pd.read_csv("Desktop/world-happiness-report-2021.csv")
 #Find Percentage of Regional so its easy to plot
 region_percentages = happiness['Regional indicator'].value_counts(normalize=True) * 100
 # Plot the chart autocpt enables to display the percentage
 plt.pie(region_percentages, labels=region_percentages.index, autopct='%1.1f%%')
 #Setting Title
 plt.title("World Happiness Index by Region")
 #Shows Plot
 plt.show()
  # Save as Image
 plt.savefig("pie.png")
    
 return

# %%
def line_chart():
 #Importing Data Set
 pop_pak = pd.read_csv('Desktop/pakistan_population.csv')
 #Plotting Fertility Rate per Year
 plt.plot(pop_pak["Year"],pop_pak["Fertility Rate"])
 # X Label 
 plt.xlabel("Year")
 #Y Label
 plt.ylabel("Fertility Rate")
 #Title of Chart
 plt.title("Pakistan Fertility from 1955 to 2020")
 #Show the Plot
 plt.show()
 # Save as Image
 plt.savefig("line.png")
 return

# %%
bar_chart()
line_chart()
pie_chart()
